# %%
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import h5py
# %matplotlib inline

# %%
file_path = './data/test/test_set.h5'

# %%
df_images = pd.read_hdf(file_path, key='images')
df_data = pd.read_hdf(file_path, key='data')
# f = h5py.File(file_path, 'r')

# %%
df_images
# Out:
#                                                  img
# 0  [[0.0509803921569, 0.0392156862745, 0.03137254...

# %%
imgs = df_images['img'][0]

# %%
for img in imgs:
    print(img)
# Out:
# [ 0.05098039  0.03921569  0.03137255 ...,  0.43529412  0.45490196
#   0.89803922]
# [ 0.04705882  0.03529412  0.02745098 ...,  0.43921569  0.51764706
#   0.94509804]
# [ 0.04705882  0.03921569  0.03137255 ...,  0.44313725  0.84705882
#   0.94117647]
# [ 0.04705882  0.04313725  0.03137255 ...,  0.43921569  0.74901961
#   0.94117647]
# [ 0.04313725  0.03529412  0.03137255 ...,  0.45490196  0.94117647
#   0.94509804]
# [ 0.03529412  0.03529412  0.02745098 ...,  0.94509804  0.94509804
#   0.94509804]
# [ 0.61568627  0.34117647  0.20784314 ...,  0.9254902   0.94117647
#   0.94117647]
# [ 0.03921569  0.03529412  0.02745098 ...,  0.94509804  0.94509804
#   0.94509804]
# [ 0.03529412  0.03529412  0.02745098 ...,  0.94509804  0.94509804
#   0.94509804]
# [ 0.02745098  0.01960784  0.02745098 ...,  0.94509804  0.94509804
#   0.94509804]
# [ 0.01960784  0.01960784  0.03529412 ...,  0.94509804  0.94509804
#   0.94509804]
# [ 0.02745098  0.01960784  0.03137255 ...,  0.94117647  0.94117647
# ...

# %%
img = imgs[0]

# %%
img
# Out:
# array([ 0.05098039,  0.03921569,  0.03137255, ...,  0.43529412,
#         0.45490196,  0.89803922])

# %%
img = img.reshape(48, 96)

# %%
plt.imshow(img)

# %%
i = 0
for img in imgs:
    i += 1
    if i > 10:
        break
    img = img.reshape(48, 96)
    plt.imshow(img)
